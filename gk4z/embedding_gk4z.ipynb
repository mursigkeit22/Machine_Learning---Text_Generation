# %% [markdown]
# Starting from the beginning, gensim’s word2vec expects a sequence of sentences as its input. Each sentence a list of words (utf8 strings):

# %%
# !pip install Cython

# %%
# !pip install --upgrade gensim
# Out:
# ...
#   Stored in directory: C:\Users\septo\AppData\Local\pip\Cache\wheels\73\6b\89\bb14fd56b74774a39a771a12f525a6a14c2c2692d3084ad048
# ...
#   Stored in directory: C:\Users\septo\AppData\Local\pip\Cache\wheels\b8\cb\43\c0ba52baf2b0e371ec1d5b2d4685d6d24617b1391f3eeacda5
# Successfully built gensim smart-open
# ...

# %%
import gensim, logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
import pandas as pd
from gensim.test.utils import common_texts, get_tmpfile
# Out:
# 2019-05-11 21:54:32,811 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2019-05-11 21:54:32,812 : INFO : built Dictionary(12 unique tokens: ['computer', 'human', 'interface', 'response', 'survey']...) from 9 documents (total 29 corpus positions)

# %%
df = pd.read_csv('gk4z_rus_clean.csv')

# %%
df
# Out:
#           id                                               text  likes  \
# 0      76914  Уже сегодня ночью (по МСК) начнётся один из са...     34
# 1      76917                       Ого, Нина Кравиц в лайн-апе😲      0
# 2      76920  [id17823823|Анастасия], с новым крутым шоу от ...      0
# 3      76922  Скину расписание на сегодня сюда. Время москов...      0
# 4      76933  [id18399319|Anastasia], неправда, в Москве вре...      0
# 5      76929  Трансляция, конечно, моё почтение. Классно выг...      1
# 6      76930  Моё увожение Блэкпинк, которые даже с живыми и...      1
# 7      76934  Часть пропустила, конец сета у SG Lewis был кл...      0
# 8      76935  сейчас посмотрела лайв Rufus Du Sol, очень бод...      0
# 9      76921  [id135469077|Мария], да он же неинтересный пол...      0
# 10     76923  [id136522683|Никита], для любителей попсы коне...      0
# 11     76924  [id135469077|Мария], если «любитель попсы» — э...      0
# ...

# %%
lines = []
for line in df.clean_text:
    lines.append(line.split())

# %%
len(lines)
# Out:
# 36283

# %%
path = get_tmpfile("gk4z_ruc_clean.model")

# %%
model = gensim.models.Word2Vec(lines, min_count=2, workers=10, size=200)
# Out:
# 2019-05-11 21:54:42,818 : INFO : collecting all words and their counts
# 2019-05-11 21:54:42,819 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2019-05-11 21:54:42,856 : INFO : PROGRESS: at sentence #10000, processed 119536 words, keeping 24862 word types
# 2019-05-11 21:54:42,892 : INFO : PROGRESS: at sentence #20000, processed 244875 words, keeping 40312 word types
# 2019-05-11 21:54:42,927 : INFO : PROGRESS: at sentence #30000, processed 367161 words, keeping 52106 word types
# 2019-05-11 21:54:42,953 : INFO : collected 58297 word types from a corpus of 447432 raw words and 36283 sentences
# 2019-05-11 21:54:42,954 : INFO : Loading a fresh vocabulary
# 2019-05-11 21:54:43,004 : INFO : effective_min_count=2 retains 22768 unique words (39% of original 58297, drops 35529)
# 2019-05-11 21:54:43,005 : INFO : effective_min_count=2 leaves 411903 word corpus (92% of original 447432, drops 35529)
# ...

# %%
model.save("gk4z_ruc_clean.model")
# Out:
# 2019-05-11 21:55:04,413 : INFO : saving Word2Vec object under gk4z_ruc_clean.model, separately None
# 2019-05-11 21:55:04,413 : INFO : not storing attribute vectors_norm
# 2019-05-11 21:55:04,414 : INFO : not storing attribute cum_table
# 2019-05-11 21:55:04,415 : WARNING : this function is deprecated, use smart_open.open instead
# 2019-05-11 21:55:04,796 : INFO : saved gk4z_ruc_clean.model
